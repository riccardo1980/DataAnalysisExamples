# %%
import scipy.io
import numpy as np
import pandas as pd
from io import StringIO
from sklearn import datasets
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
d = datasets.load_wine()
print("observations: %d, features: %d" % d.data.shape)
print("Feature names: %s" % ', '.join(d.feature_names))

df = pd.DataFrame(d.data, columns=d.feature_names)
df['y'] = d.target
df.head(8)
# Out:
# observations: 178, features: 13
# Feature names: alcohol, malic_acid, ash, alcalinity_of_ash, magnesium, total_phenols, flavanoids, nonflavanoid_phenols, proanthocyanins, color_intensity, hue, od280/od315_of_diluted_wines, proline
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
# 7    14.06        2.15  2.61               17.6      121.0           2.60
#
# ...

# %%
# Get stats from DataFrame
pd.set_option('precision',3)
df.drop('y', axis=1).describe()
# Out:
#        alcohol  malic_acid      ash  alcalinity_of_ash  magnesium  \
# count  178.000     178.000  178.000            178.000    178.000
# mean    13.001       2.336    2.367             19.495     99.742
# std      0.812       1.117    0.274              3.340     14.282
# min     11.030       0.740    1.360             10.600     70.000
# 25%     12.362       1.603    2.210             17.200     88.000
# 50%     13.050       1.865    2.360             19.500     98.000
# 75%     13.678       3.083    2.558             21.500    107.000
# max     14.830       5.800    3.230             30.000    162.000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count        178.000     178.000               178.000          178.000
# mean           2.295       2.029                 0.362            1.591
# std            0.626       0.999                 0.124            0.572
# min            0.980       0.340                 0.130            0.410
# ...

# %%
# get elements for each class: frequency of labels on column 'y'
df['y'].value_counts()
# Out:
# 1    71
# 0    59
# 2    48
# Name: y, dtype: int64

# %%
colors = ['#006CD1', '#26D100', '#D10000']
color_series = [ colors[i] for i in df['y'] ]
pd.plotting.scatter_matrix(df[df.columns[:4]], figsize=(7, 7),
                                 c=color_series, diagonal='hist', marker='.')
plt.show()
